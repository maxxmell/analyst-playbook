# %% [markdown]
# # SQL ПЛЭЙБУК: Полный справочник шаблонов и функций для аналитиков
#
# ## СОДЕРЖАНИЕ
# [РАЗДЕЛ 1: ФУНДАМЕНТАЛЬНЫЕ ОСНОВЫ](#раздел-1-фундаментальные-основы)
# [РАЗДЕЛ 2: ВЫБОРКА И ФИЛЬТРАЦИЯ ДАННЫХ](#раздел-2-выборка-и-фильтрация-данных)
# [РАЗДЕЛ 3: АГРЕГАЦИЯ И ГРУППИРОВКА](#раздел-3-агрегация-и-группировка)
# [РАЗДЕЛ 4: СОЕДИНЕНИЯ ТАБЛИЦ (JOINs)](#раздел-4-соединения-таблиц-joins)
# [РАЗДЕЛ 5: ПОДЗАПРОСЫ (SUBQUERIES)](#раздел-5-подзапросы-subqueries)
# [РАЗДЕЛ 6: CTE (COMMON TABLE EXPRESSIONS)](#раздел-6-cte-common-table-expressions)
# [РАЗДЕЛ 7: ОКОННЫЕ ФУНКЦИИ](#раздел-7-оконные-функции)
# [РАЗДЕЛ 8: ОПТИМИЗАЦИЯ И ИНДЕКСЫ](#раздел-8-оптимизация-и-индексы)
# [РАЗДЕЛ 9: ТРАНЗАКЦИИ И УПРАВЛЕНИЕ](#раздел-9-транзакции-и-управление)
# [РАЗДЕЛ 10: РАБОТА С ДАТАМИ И СТРОКАМИ](#раздел-10-работа-с-датами-и-строками)
# [РАЗДЕЛ 11: ПРОДВИНУТЫЕ ТЕМЫ](#раздел-11-продвинутые-темы)
# [РАЗДЕЛ 12: ПРАКТИЧЕСКИЕ ПАТТЕРНЫ И ЗАДАЧИ](#раздел-12-практические-паттерны-и-задачи)
# [ПРИЛОЖЕНИЯ](#приложения)
#
# ---
